# %% [markdown]
# # Numerical Regression
#
# This notebook runs the numerical regression part of the project using the same source code used by `main.py`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.numerical.utils import run_numerical_pipeline

# %%
results = run_numerical_pipeline()
results['metadata']

# %%
results['linear_regression']['test_metrics'], results['knn_regressor']['test_metrics']
