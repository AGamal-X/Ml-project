# %% [markdown]
# # Image Classification
#
# This notebook runs the image classification and KMeans cluster-labeling part of the project using the same source code used by `main.py`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.image.utils import run_image_pipeline

# %%
results = run_image_pipeline()
results['metadata']

# %%
results['logistic_regression']['test_metrics']['accuracy'], results['kmeans']['test_metrics']['accuracy']
